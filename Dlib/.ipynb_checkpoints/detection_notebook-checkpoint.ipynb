# %%
from os import listdir, chdir, path
from skimage import io
import time
import dlib

chdir('/home/franciscollaneza/dlib')
predictor_path = "python_examples/shape_predictor_5_face_landmarks.dat"
face_rec_model_path = "python_examples/dlib_face_recognition_resnet_model_v1.dat"
faces_folder_path = "examples/faces"

# %%
files = listdir(faces_folder_path, )
image_files = [file for file in files if file.endswith('.jpg')]
image_files[0:5]
# Out:
# ['hmgula.13.jpg',
#  'ian_exp.3.jpg',
#  'and_exp.1.jpg',
#  'glen_exp.13.jpg',
#  'john_exp.1.jpg']

# %%
detector = dlib.get_frontal_face_detector()
detected_faces = list()

win = dlib.image_window()

for f in image_files:
    print("Processing image: {}".format(f))
    img = io.imread(path.join(faces_folder_path, f))
    # The 1 in the second argument indicates that we should upsample the image
    # 1 time.  This will make everything bigger and allow us to detect more
    # faces.
    dets = detector(img, 1)
    print "Number of faces detected: {}".format(len(dets))
    print ""
    for i, d in enumerate(dets):
        face = img[d.top():d.bottom(), d.left():d.right(),:]
        detected_faces.append(face)
        # print("Detection {}: Left: {} Top: {} Right: {} Bottom: {}".format(i, d.left(), d.top(), d.right(), d.bottom()))

    win.clear_overlay()
    win.set_image(img)
    win.add_overlay(dets)
# Out:
# Processing image: hmgula.13.jpg
# Number of faces detected: 1
#
# Processing image: ian_exp.3.jpg
# Number of faces detected: 1
#
# Processing image: and_exp.1.jpg
# Number of faces detected: 1
#
# Processing image: glen_exp.13.jpg
# Number of faces detected: 1
#
# Processing image: john_exp.1.jpg
# Number of faces detected: 1
#
# Processing image: pat_exp.3.jpg
# Number of faces detected: 1
#
# Processing image: ant_exp.13.jpg
# Number of faces detected: 1
#
# Processing image: glen_exp.1.jpg
# Number of faces detected: 1
#
# Processing image: lib_exp.19.jpg
# Number of faces detected: 1
#
# Processing image: pat_exp.19.jpg
# Number of faces detected: 1
#
# Processing image: oegill.7.jpg
# Number of faces detected: 1
#
# Processing image: chr_exp.13.jpg
# Number of faces detected: 1
#
# Processing image: mike_exp.13.jpg
# Number of faces detected: 1
#
# Processing image: chr_exp.19.jpg
# Number of faces detected: 1
#
# Processing image: ireloz.4.jpg
# Number of faces detected: 1
#
# ...
